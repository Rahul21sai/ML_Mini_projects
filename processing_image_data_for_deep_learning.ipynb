# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul21sai/ML_Mini_projects/blob/main/processing_image_data_for_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# image data processing

# %%
#getting an image using web get
# !wget 'https://www.thesprucepets.com/thmb/hxWjs7evF2hP1Fb1c1HAvRi_Rw0=/2765x0/filters:no_upscale():strip_icc()/chinese-dog-breeds-4797219-hero-2a1e9c5ed2c54d00aef75b05c5db399c.jpg'
# Out:
# --2023-09-27 18:10:28--  https://www.thesprucepets.com/thmb/hxWjs7evF2hP1Fb1c1HAvRi_Rw0=/2765x0/filters:no_upscale():strip_icc()/chinese-dog-breeds-4797219-hero-2a1e9c5ed2c54d00aef75b05c5db399c.jpg
# Resolving www.thesprucepets.com (www.thesprucepets.com)... 151.101.2.137, 151.101.66.137, 151.101.130.137, ...
# Connecting to www.thesprucepets.com (www.thesprucepets.com)|151.101.2.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 638178 (623K) [image/jpeg]
# Saving to: ‘chinese-dog-breeds-4797219-hero-2a1e9c5ed2c54d00aef75b05c5db399c.jpg.1’
#
# chinese-dog-breeds- 100%[===================>] 623.22K  --.-KB/s    in 0.04s
#
# 2023-09-27 18:10:28 (15.5 MB/s) - ‘chinese-dog-breeds-4797219-hero-2a1e9c5ed2c54d00aef75b05c5db399c.jpg.1’ saved [638178/638178]

# %% [markdown]
# libraries used for image processing\n
# 1 matplotlib
# 2 open cv
# 3 pillow

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/dog.jpg.1')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1843, 2765, 3)

# %%
print(img)
# Out:
# [[[142 139 150]
#   [141 138 149]
#   [141 138 149]
#   ...
#   [160 137 119]
#   [161 138 120]
#   [161 138 120]]
#
#  [[141 138 149]
#   [141 138 149]
#   [141 138 149]
#   ...
#   [161 138 120]
#   [162 139 121]
#   [162 139 121]]
#
#  [[141 138 149]
#   [141 138 149]
#   [142 139 150]
#   ...
#   [161 138 120]
#   [162 139 121]
#   [164 141 123]]
#
#  ...
#
#  [[ 87 130  58]
#   [ 83 126  54]
#   [ 79 122  50]
#   ...
#   [ 52  93  23]
#   [ 53  94  24]
#   [ 54  95  25]]
#
#  [[ 88 131  60]
#   [ 85 128  57]
#   [ 81 124  53]
#   ...
#   [ 53  92  25]
#   [ 54  93  26]
#   [ 54  94  24]]
#
#  [[ 89 132  61]
#   [ 86 129  58]
#   [ 84 127  56]
#   ...
#   [ 53  92  25]
#   [ 52  91  24]
#   [ 52  92  22]]]

# %%
# reverse the process numpy to image
img_plot = plt.imshow(img)
plt.show()

# %%
# resizing the image in pillow library
from PIL import Image

# %%
img = Image.open('/content/dog.jpg.1')
img_resize = img.resize((200,200))

# %%
img_resize.save('dog_resize.jpg')

# %%
imgr= mpimg.imread('/content/dog_resize.jpg')
imgr_plot = plt.imshow(imgr)
plt.show()

# %%
print(imgr.shape)
# Out:
# (200, 200, 3)

# %%
print(imgr)
# Out:
# [[[143 137 149]
#   [142 136 148]
#   [140 134 146]
#   ...
#   [144 124 115]
#   [154 132 121]
#   [156 134 123]]
#
#  [[143 137 149]
#   [140 137 148]
#   [140 134 146]
#   ...
#   [150 130 121]
#   [162 139 131]
#   [166 144 133]]
#
#  [[141 137 151]
#   [139 137 150]
#   [139 135 149]
#   ...
#   [153 134 128]
#   [166 146 139]
#   [173 153 144]]
#
#  ...
#
#  [[ 76 123  27]
#   [ 83 130  38]
#   [ 82 127  46]
#   ...
#   [ 59 102  46]
#   [ 72 115  59]
#   [ 78 121  65]]
#
#  [[ 80 127  35]
#   [ 88 134  46]
#   [ 82 127  46]
#   ...
#   [ 55  98  42]
#   [ 63 106  50]
#   [ 64 108  49]]
#
#  [[ 79 125  35]
#   [ 89 135  47]
#   [ 83 128  47]
#   ...
#   [ 61 104  48]
#   [ 61 104  48]
#   [ 57 101  42]]]

# %%
# converting rgb images into gray scale using openCV
import cv2

# %%
img =cv2.imread('/content/dog.jpg.1')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1843, 2765, 3)

# %%
gimg = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(gimg)
# Out:
# numpy.ndarray

# %%
gimg.shape
# Out:
# (1843, 2765)

# %%
# cv2.imshow() will dispaly image in others but this not work in colab
# so use
from google.colab.patches import cv2_imshow

# %%
#display grey scaple img
cv2_imshow(gimg)
# Out:
# <PIL.Image.Image image mode=L size=2765x1843>

# %%
#save the imgage
cv2.imwrite('d_gimg.jpg',gimg)
# Out:
# True
